# %%
import os
import sys
import importlib.util

is_installed = importlib.util.find_spec("gtsystem")
if not is_installed:
    print ('Not using PyPi')
    module_path = ".."
    sys.path.append(os.path.abspath(module_path))
else:
    print ('Loaded gtsystem')

from gtsystem import leaderboard, render

# %%
leaders = leaderboard.read_leaderboard('../data/leaderboard-2024-0413.xlsx')
render.df(leaders, 10)
# Out:
# <style type="text/css">
# #T_a9863 th {
#   font-size: 10pt;
#   text-align: left;
# }
# #T_a9863 td {
#   text-align: left;
#   word-wrap: break-word;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# #T_a9863 .index_name {
#   display: none;
# }
# #T_a9863 .row_heading {
#   display: none;
# }
# #T_a9863  .blank {
#   display: none;
# }
# </style>
# <table id="T_a9863">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9863_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_a9863_level0_col1" class="col_heading level0 col1" >Model</th>
#       <th id="T_a9863_level0_col2" class="col_heading level0 col2" >Elo</th>
#       <th id="T_a9863_level0_col3" class="col_heading level0 col3" >Voted</th>
#       <th id="T_a9863_level0_col4" class="col_heading level0 col4" >Organization</th>
#       <th id="T_a9863_level0_col5" class="col_heading level0 col5" >License</th>
# ...

# %%
render.df(leaderboard.model('GPT-4'))
# Out:
# <style type="text/css">
# #T_ade99 th {
#   font-size: 10pt;
#   text-align: left;
# }
# #T_ade99 td {
#   text-align: left;
#   word-wrap: break-word;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# #T_ade99 .index_name {
#   display: none;
# }
# #T_ade99 .row_heading {
#   display: none;
# }
# #T_ade99  .blank {
#   display: none;
# }
# </style>
# <table id="T_ade99">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ade99_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_ade99_level0_col1" class="col_heading level0 col1" >Model</th>
#       <th id="T_ade99_level0_col2" class="col_heading level0 col2" >Elo</th>
#       <th id="T_ade99_level0_col3" class="col_heading level0 col3" >Voted</th>
#       <th id="T_ade99_level0_col4" class="col_heading level0 col4" >Organization</th>
#       <th id="T_ade99_level0_col5" class="col_heading level0 col5" >License</th>
# ...

# %%
render.df(leaderboard.vendor('Anthropic'))
# Out:
# <style type="text/css">
# #T_02ec0 th {
#   font-size: 10pt;
#   text-align: left;
# }
# #T_02ec0 td {
#   text-align: left;
#   word-wrap: break-word;
#   overflow: hidden;
#   text-overflow: ellipsis;
# }
# #T_02ec0 .index_name {
#   display: none;
# }
# #T_02ec0 .row_heading {
#   display: none;
# }
# #T_02ec0  .blank {
#   display: none;
# }
# </style>
# <table id="T_02ec0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_02ec0_level0_col0" class="col_heading level0 col0" >Rank</th>
#       <th id="T_02ec0_level0_col1" class="col_heading level0 col1" >Model</th>
#       <th id="T_02ec0_level0_col2" class="col_heading level0 col2" >Elo</th>
#       <th id="T_02ec0_level0_col3" class="col_heading level0 col3" >Voted</th>
#       <th id="T_02ec0_level0_col4" class="col_heading level0 col4" >Organization</th>
#       <th id="T_02ec0_level0_col5" class="col_heading level0 col5" >License</th>
# ...
